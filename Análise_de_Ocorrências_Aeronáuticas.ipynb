# %% [markdown]
# <a href="https://colab.research.google.com/github/nandodevs/etl-ocorrencias-aeronauticas/blob/main/An%C3%A1lise_de_Ocorr%C3%AAncias_Aeron%C3%A1uticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![33ba8d9b-4cff-46b8-ac2a-ef04f5ffad54.jpeg](data:image/jpeg;base64,...)
#
# # **Análise de Ocorrências Aeronáticas Brasileiras por meio de ETL.**

# %%
# Bibliotecas
import pandas as pd

# Ignorar warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Carregar dataset, definir separador e convertar formato data
df = pd.read_csv('ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)

# 5 primeiras linhas
df.head()

# %%
# 5 últimas linhas
df.tail()

# %%
# tipos de dados
df.dtypes

# %%
df.ocorrencia_dia.dt.month
